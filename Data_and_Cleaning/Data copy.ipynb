# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot

# %%
df = pd.read_csv('cs-training.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df2 = pd.read_csv('sampleEntry.csv')

# %%
df2.head()
# Out:
#    Id  Probability
# 0   1     0.080807
# 1   2     0.040719
# 2   3     0.011968
# 3   4     0.067640
# 4   5     0.108264

# %%
df = df.drop(columns='Unnamed: 0', axis=1)

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149997                 0                              0.246044   58
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          2     0.802982         9120.0
# ...

# %%
y = df['SeriousDlqin2yrs']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        150000 non-null int64
# RevolvingUtilizationOfUnsecuredLines    150000 non-null float64
# age                                     150000 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    150000 non-null int64
# DebtRatio                               150000 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         150000 non-null int64
# NumberOfTimes90DaysLate                 150000 non-null int64
# NumberRealEstateLoansOrLines            150000 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    150000 non-null int64
# NumberOfDependents                      146076 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 12.6 MB

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# ...

# %% [markdown]
# ## Initial Data Exploration

# %%
cols = list(df.columns)

# %%
hist = df[cols].hist(figsize=[20,15])

# %%
from yellowbrick.datasets import load_game
from yellowbrick.target import ClassBalance

# Instantiate the visualizer
visualizer = ClassBalance(labels=["NoDel", "Del"])

visualizer.fit(y)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
y
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: SeriousDlqin2yrs, Length: 150000, dtype: int64

# %%
y_counts = y.value_counts()

# %%
y_counts
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
y_total = y.count()

# %%
y_counts/y_total
# Out:
# 0    0.93316
# 1    0.06684
# Name: SeriousDlqin2yrs, dtype: float64

# %%
sns.distplot(df["RevolvingUtilizationOfUnsecuredLines"], hist=False)

# %%
df["RevolvingUtilizationOfUnsecuredLines"].describe()
# Out:
# count    150000.000000
# mean          6.048438
# std         249.755371
# min           0.000000
# 25%           0.029867
# 50%           0.154181
# 75%           0.559046
# max       50708.000000
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
df.boxplot(column='RevolvingUtilizationOfUnsecuredLines')

# %%
df['RevolvingUtilizationOfUnsecuredLines'].sort_values()
# Out:
# 63253         0.0
# 91220         0.0
# 42672         0.0
# 130152        0.0
# 53417         0.0
#            ...
# 149279    20514.0
# 149160    22000.0
# 16956     22198.0
# 31414     29110.0
# 85489     50708.0
# Name: RevolvingUtilizationOfUnsecuredLines, Length: 150000, dtype: float64

# %%
remo_ol_ru = df.loc[df['RevolvingUtilizationOfUnsecuredLines'] >= .0]

# %%
len(remo_ol_ru)
# Out:
# 150000

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
df.corr()
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                              1.000000
# RevolvingUtilizationOfUnsecuredLines         -0.001802
# age                                          -0.115386
# NumberOfTime30-59DaysPastDueNotWorse          0.125587
# DebtRatio                                    -0.007602
# MonthlyIncome                                -0.019746
# NumberOfOpenCreditLinesAndLoans              -0.029669
# NumberOfTimes90DaysLate                       0.117175
# NumberRealEstateLoansOrLines                 -0.007038
# NumberOfTime60-89DaysPastDueNotWorse          0.102261
# NumberOfDependents                            0.046048
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                 -0.001802
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005898
# ...

# %%
df.isna().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
df['MonthlyIncome'].describe()
# Out:
# count    1.202690e+05
# mean     6.670221e+03
# std      1.438467e+04
# min      0.000000e+00
# 25%      3.400000e+03
# 50%      5.400000e+03
# 75%      8.249000e+03
# max      3.008750e+06
# Name: MonthlyIncome, dtype: float64

# %%
df.boxplot(column='MonthlyIncome')

# %%
df['MonthlyIncome'].sort_values(ascending=False).head(10)
# Out:
# 73763     3008750.0
# 137140    1794060.0
# 111365    1560100.0
# 50640     1072500.0
# 122543     835040.0
# 123291     730483.0
# 93564      702500.0
# 96549      699530.0
# 119136     649587.0
# 37078      629000.0
# Name: MonthlyIncome, dtype: float64

# %%
df.loc[df['MonthlyIncome'] <= 1000000 ]
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149994                 0                              0.385742   50
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                          2   0.802982         9120.0
# ...

# %%
df = df.loc[df['MonthlyIncome'] <= 1000000 ]

# %%
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149994                 0                              0.385742   50
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                          2   0.802982         9120.0
# ...

# %%
df.isna().sum()
# Out:
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# age                                     0
# NumberOfTime30-59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60-89DaysPastDueNotWorse    0
# NumberOfDependents                      0
# dtype: int64

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     120265.000000                         120265.000000  120265.000000
# mean           0.069488                              5.900063      51.289768
# std            0.254284                            257.044957      14.426812
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.035086      40.000000
# 50%            0.000000                              0.177303      51.000000
# 75%            0.000000                              0.579428      61.000000
# max            1.000000                          50708.000000     103.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120265.000000  120265.000000  120265.000000
# mean                               0.381774      26.599662    6608.617869
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120265 entries, 0 to 149999
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        120265 non-null int64
# RevolvingUtilizationOfUnsecuredLines    120265 non-null float64
# age                                     120265 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    120265 non-null int64
# DebtRatio                               120265 non-null float64
# MonthlyIncome                           120265 non-null float64
# NumberOfOpenCreditLinesAndLoans         120265 non-null int64
# NumberOfTimes90DaysLate                 120265 non-null int64
# NumberRealEstateLoansOrLines            120265 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    120265 non-null int64
# NumberOfDependents                      120265 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 11.0 MB

# %% [markdown]
# ## EDA

# %%
sns.distplot(df["MonthlyIncome"], hist=False)

# %%
sns.distplot(df["RevolvingUtilizationOfUnsecuredLines"], hist=False)

# %%
sns.distplot(df["MonthlyIncome"]);

# %%
y = df['SeriousDlqin2yrs']

# %%
from yellowbrick.datasets import load_game
from yellowbrick.target import ClassBalance

# Instantiate the visualizer
visualizer = ClassBalance(labels=["NoDel", "Del"])

visualizer.fit(y)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
sns.catplot(x="SeriousDlqin2yrs", y="MonthlyIncome", data=df);

# %%
sns.catplot(x="SeriousDlqin2yrs", y="DebtRatio", data=df);

# %%
sns.catplot(x="SeriousDlqin2yrs", y="age", data=df);

# %%
sns.catplot(x="SeriousDlqin2yrs", y="age", kind="box", data=df);

# %%
sns.catplot(x="SeriousDlqin2yrs", y="RevolvingUtilizationOfUnsecuredLines", data=df);

# %%
sns.set_style("dark")
sns.pairplot(df)

# %%
sns.catplot(x="SeriousDlqin2yrs", kind="count", palette="pastel", data=df);

# %%
sns.catplot(x="NumberOfTime30-59DaysPastDueNotWorse", y="age", data=df);

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
# df.to_csv ('cleaned_df.csv')
